# %%
import pandas as pd #unstructured data to structured data
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\pragy\Desktop\RAIT\3 year\sem5\7.SBL(Python)\prac and viva\bank.csv") #data frame which is multi dimensional unlike data series

# %%
df.head(9) #read the first 5 rows
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# ...

# %%
df.tail(10) # read bottom 5 rows
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11152   34    housemaid  married  secondary      no      390     yes   no
# 11153   43       admin.   single  secondary      no       35      no   no
# 11154   52   technician  married   tertiary      no      523     yes  yes
# 11155   35  blue-collar  married  secondary      no       80     yes  yes
# 11156   34  blue-collar   single  secondary      no      -72     yes   no
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 11152   cellular   15   jul       659         3     -1         0  unknown
# ...

# %%
df.columns #reading the columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
df['marital'] #read single column
# Out:
# 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 11157     single
# 11158    married
# 11159     single
# 11160    married
# 11161    married
# Name: marital, Length: 11162, dtype: object

# %%
df[['job','education']]
# Out:
#                job  education
# 0           admin.  secondary
# 1           admin.  secondary
# 2       technician  secondary
# 3         services  secondary
# 4           admin.   tertiary
# ...            ...        ...
# 11157  blue-collar    primary
# 11158     services  secondary
# 11159   technician  secondary
# 11160   technician  secondary
# 11161   technician  secondary
#
# [11162 rows x 2 columns]

# %%
df.iloc[:5] #read first 5 rows
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df.iloc[:,:2] #all the rows and first two columns
# Out:
#        age          job
# 0       59       admin.
# 1       56       admin.
# 2       41   technician
# 3       55     services
# 4       54       admin.
# ...    ...          ...
# 11157   33  blue-collar
# 11158   39     services
# 11159   32   technician
# 11160   43   technician
# 11161   34   technician
#
# [11162 rows x 2 columns]

# %%
df.shape #dimensions
# Out:
# (11162, 17)

# %%
#define a dictionary containing user details
data1 = {
    'age': [29,64,35],
    'job': ['technical','admin','services'],
    'marital': ['single','married','single'],
}

data2 = {
    'age': [15,85,40],
    'job': ['school','admin','services'],
    'marital': ['single','married','single'],
}
#convert the dictionary into DataFrames
df1 = pd.DataFrame(data1, index=[0, 1, 2])
df2 = pd.DataFrame(data2, index=[3, 4, 5])

print(df1,'\n\n',df2)
# Out:
#    age        job  marital
# 0   29  technical   single
# 1   64      admin  married
# 2   35   services   single
#
#     age       job  marital
# 3   15    school   single
# 4   85     admin  married
# 5   40  services   single

# %%
#using a concat() method 
frames = [df1, df2]
res1 = pd.concat(frames)
res1
# Out:
#    age        job  marital
# 0   29  technical   single
# 1   64      admin  married
# 2   35   services   single
# 3   15     school   single
# 4   85      admin  married
# 5   40   services   single

# %%
res1['education'] = ['primary','secondary','tertiary','primary','tertiary','tertiary']

# %%
# primary = res1[df['education'] == 'primary']

# %%
print(res1)
# Out:
#    age        job  marital  education
# 0   29  technical   single    primary
# 1   64      admin  married  secondary
# 2   35   services   single   tertiary
# 3   15     school   single    primary
# 4   85      admin  married   tertiary
# 5   40   services   single   tertiary
